# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    u = np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(batch - u)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %%
def relu(batch, stochastic=False):
    if stochastic:
        return np.maximum(0, batch + np.random.normal(scale=np.std(batch), size=batch.shape))
    
    else:
        return np.maximum(0, batch)
        

def relu_derivative(batch):
    return np.where(batch <= 0, 0, 1)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights, limit):
    limits = ones(*weights.shape)
    col_norms = np.linalg.norm(weights, axis=0)
    limits[:, col_norms > limit] = limit / col_norms[col_norms > limit]


    return weights * limits

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):    
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        
        # Construct boolean mask for visible layer dropout.
        dropout_mask_visible = rand(
            batch.shape[0], batch.shape[1] - 1
        ) >= mlp[0].dropout_rate
        
        batch[:, :-1] = batch[:, :-1] * dropout_mask_visible
        
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        preactivation_z = visible @ layer.W
        activation = layer.activation_fun(preactivation_z)
        layer.activations = append_ones(activation)
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(preactivation_z)
            
            if mlp[layer_idx+1].dropout_rate > 0:
                # Construct boolean mask for hidden layer dropout.
                # We do not need to cut off biases, as append_ones was done
                # only for activations. d_activations has been calcluated based
                # on preactivation_z thus without additional ones.
                dropout_mask_hidden = rand(
                    layer.d_activations.shape[0],
                    layer.d_activations.shape[1]
                ) >= mlp[layer_idx+1].dropout_rate
        
                layer.activations[:, :-1] = layer.activations[:, :-1] * dropout_mask_hidden
                
                # We do not cut biases off according to the aforementioned description.
                # We should use the same mask!
                layer.d_activations = layer.d_activations * dropout_mask_hidden
            
        visible = layer.activations
    
    return visible[:, :-1], batch

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
            # Transposition is needed. layer.W is adjusted to the "forward" direction.
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M
        
        # Ograniczenie wag normą wektora
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]

    for layer in mlp:
        layer.W[:-1, :] *= 1 - layer.dropout_rate

    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        # In this implementation with dropout, we need to catch batch without dropout
        # to make backpropagation.
        y, batch_without_dropout = forward_pass(mlp, batch, True)

        mlp[-1].deltas = y - batch_labels
        # Inicjalizujemy deltas -> różnica między tym co wyszło w sieci a tym co miało wyjść.

        # Once softmax deltas are set, we may backpropagate errors
        # Nie liczymy error bakpropagacje na batchu z dropoutem bo nie możemy zrobić dropoutu
        # na ostatniej warstwie softmax.
        error_backpropagate(mlp, batch_without_dropout)

        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.learning_rate = 0.15
        elif epoch == 150:
            for layer in mlp:
                layer.momentum = 0.925
                layer.learning_rate = 0.1
        elif epoch == 175:
            for layer in mlp:
                layer.momentum = 0.9
                layer.learning_rate = 0.01
                
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 5000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 1024

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=2.5)
]

evaluate(mlp, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 2.35s, accuracy: 15.36
# Epoch 2:	########################################	elapsed: 2.50s, accuracy: 45.64
# Epoch 3:	########################################	elapsed: 2.57s, accuracy: 68.50
# Epoch 4:	########################################	elapsed: 2.36s, accuracy: 74.85
# Epoch 5:	########################################	elapsed: 2.51s, accuracy: 79.92
# Epoch 6:	########################################	elapsed: 2.34s, accuracy: 85.85
# Epoch 7:	########################################	elapsed: 2.35s, accuracy: 90.14
# Epoch 8:	########################################	elapsed: 2.37s, accuracy: 92.11
# Epoch 9:	########################################	elapsed: 2.32s, accuracy: 92.17
# Epoch 117:	########################################	elapsed: 2.57s, accuracy: 96.28
# Epoch 118:	########################################	elapsed: 2.68s, accuracy: 96.37
# Epoch 119:	########################################	elapsed: 2.66s, accuracy: 96.55
# Epoch 120:	########################################	elapsed: 2.62s, accuracy: 96.73
# Epoch 121:	########################################	elapsed: 2.56s, accuracy: 96.67
# Epoch 122:	########################################	elapsed: 2.54s, accuracy: 96.11
# Epoch 123:	########################################	elapsed: 2.51s, accuracy: 96.78
# Epoch 124:	########################################	elapsed: 2.53s, accuracy: 96.25
# Epoch 125:	########################################	elapsed: 2.56s, accuracy: 96.50
# Epoch 126:	########################################	elapsed: 2.58s, accuracy: 96.35
# Epoch 127:	########################################	elapsed: 2.60s, accuracy: 96.60
# Epoch 128:	########################################	elapsed: 2.59s, accuracy: 96.46
# Epoch 129:	########################################	elapsed: 2.58s, accuracy: 96.26
# Epoch 130:	########################################	elapsed: 2.54s, accuracy: 96.50
# Epoch 131:	########################################	elapsed: 2.91s, accuracy: 96.07
# Epoch 132:	########################################	elapsed: 2.83s, accuracy: 96.44
# Epoch 133:	########################################	elapsed: 2.86s, accuracy: 96.24
# Epoch 134:	########################################	elapsed: 2.62s, accuracy: 96.32
# Epoch 135:	########################################	elapsed: 2.56s, accuracy: 96.63
# Epoch 136:	########################################	elapsed: 2.55s, accuracy: 96.49
# Epoch 137:	########################################	elapsed: 2.60s, accuracy: 96.18
# Epoch 138:	########################################	elapsed: 2.54s, accuracy: 96.35
# Epoch 139:	########################################	elapsed: 4.10s, accuracy: 96.05
# Epoch 140:	########################################	elapsed: 6.17s, accuracy: 96.32
# Epoch 141:	########################################	elapsed: 4.62s, accuracy: 96.27
# Epoch 142:	########################################	elapsed: 4.31s, accuracy: 96.29
# Epoch 143:	########################################	elapsed: 2.77s, accuracy: 96.84
# Epoch 144:	########################################	elapsed: 2.57s, accuracy: 96.36
# Epoch 145:	########################################	elapsed: 2.52s, accuracy: 96.56
# Epoch 146:	########################################	elapsed: 2.52s, accuracy: 96.54
# Epoch 147:	########################################	elapsed: 2.51s, accuracy: 96.54
# Epoch 148:	########################################	elapsed: 2.51s, accuracy: 96.50
# Epoch 149:	########################################	elapsed: 2.52s, accuracy: 96.28
# Epoch 150:	########################################	elapsed: 2.54s, accuracy: 96.61
# Epoch 151:	########################################	elapsed: 2.52s, accuracy: 96.33
# Epoch 152:	########################################	elapsed: 2.50s, accuracy: 96.70
# Epoch 153:	########################################	elapsed: 2.56s, accuracy: 96.80
# Epoch 154:	########################################	elapsed: 2.51s, accuracy: 96.68
# Epoch 155:	########################################	elapsed: 2.50s, accuracy: 96.57
# Epoch 156:	########################################	elapsed: 2.49s, accuracy: 96.55
# Epoch 157:	########################################	elapsed: 2.49s, accuracy: 96.65
# Epoch 158:	########################################	elapsed: 2.57s, accuracy: 96.82
# Epoch 159:	########################################	elapsed: 2.67s, accuracy: 96.68
# Epoch 160:	########################################	elapsed: 3.30s, accuracy: 96.76
# Epoch 161:	########################################	elapsed: 3.36s, accuracy: 96.51
# Epoch 162:	########################################	elapsed: 2.70s, accuracy: 96.71
# Epoch 163:	########################################	elapsed: 2.63s, accuracy: 96.68
# Epoch 164:	########################################	elapsed: 2.60s, accuracy: 96.72
# Epoch 165:	########################################	elapsed: 2.58s, accuracy: 96.78
# Epoch 166:	########################################	elapsed: 2.58s, accuracy: 96.76
# Epoch 167:	########################################	elapsed: 2.58s, accuracy: 96.75
# Epoch 168:	########################################	elapsed: 2.56s, accuracy: 96.90
# Epoch 169:	########################################	elapsed: 2.57s, accuracy: 96.79
# Epoch 170:	########################################	elapsed: 2.57s, accuracy: 96.78
# Epoch 171:	########################################	elapsed: 2.52s, accuracy: 96.83
# Epoch 172:	########################################	elapsed: 2.66s, accuracy: 96.81
# Epoch 173:	########################################	elapsed: 2.78s, accuracy: 96.76
# Epoch 174:	########################################	elapsed: 2.65s, accuracy: 96.83
# Epoch 175:	########################################	elapsed: 2.61s, accuracy: 96.82
# Epoch 176:	########################################	elapsed: 2.59s, accuracy: 96.82
# Epoch 177:	########################################	elapsed: 2.47s, accuracy: 96.78
# Epoch 178:	########################################	elapsed: 2.48s, accuracy: 96.83
# Epoch 179:	########################################	elapsed: 2.48s, accuracy: 96.83
# Epoch 180:	########################################	elapsed: 2.46s, accuracy: 96.83
# Epoch 181:	########################################	elapsed: 2.55s, accuracy: 96.83
# Epoch 182:	########################################	elapsed: 2.55s, accuracy: 96.78
# Epoch 183:	########################################	elapsed: 2.50s, accuracy: 96.79
# Epoch 184:	########################################	elapsed: 2.46s, accuracy: 96.74
# Epoch 185:	########################################	elapsed: 2.50s, accuracy: 96.73
# Epoch 186:	########################################	elapsed: 2.47s, accuracy: 96.73
# Epoch 187:	########################################	elapsed: 2.48s, accuracy: 96.72
# Epoch 188:	########################################	elapsed: 2.47s, accuracy: 96.73
# Epoch 189:	########################################	elapsed: 2.50s, accuracy: 96.71
# Epoch 190:	########################################	elapsed: 2.51s, accuracy: 96.71
# Epoch 191:	########################################	elapsed: 2.63s, accuracy: 96.75
# Epoch 192:	########################################	elapsed: 2.52s, accuracy: 96.76
# Epoch 193:	########################################	elapsed: 2.66s, accuracy: 96.79
# Epoch 194:	########################################	elapsed: 2.96s, accuracy: 96.78
# Epoch 195:	########################################	elapsed: 2.64s, accuracy: 96.78
# Epoch 196:	########################################	elapsed: 2.61s, accuracy: 96.78
# Epoch 197:	########################################	elapsed: 2.62s, accuracy: 96.77
# Epoch 198:	########################################	elapsed: 2.62s, accuracy: 96.79
# Epoch 199:	########################################	elapsed: 2.60s, accuracy: 96.81
# Epoch 200:	########################################	elapsed: 2.49s, accuracy: 96.78
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 2.00
# 	layer 3: 2.50

# %%
# Dlaczego więcej epok 200 w porównaniu z 50 epokami w labie poprzednim?
# Aby zauważyć że na dropoucie nie będzie overfittingu!
