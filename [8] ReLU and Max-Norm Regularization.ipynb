# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    u = np.max(batch, axis=-1, keepdims=True)
    numerator = np.exp(batch - u)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic:
        return np.maximum(0, batch + np.random.normal(scale=np.std(batch), size=batch.shape))
    
    else:
        return np.maximum(0, batch)
        

def relu_derivative(batch):
    return np.where(batch <= 0, 0, 1)

# %%
def limit_weights(weights, limit):
    limits = ones(*weights.shape)
    col_norms = np.linalg.norm(weights, axis=0)
    limits[:, col_norms > limit] = limit / col_norms[col_norms > limit]


    return weights * limits

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit

        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch

    for layer_idx, layer in enumerate(mlp):
        preactivation_z = visible @ layer.W
        activation = layer.activation_fun(preactivation_z)
        layer.activations = append_ones(activation)

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(preactivation_z)

        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
            # Transposition is needed. layer.W is adjusted to the "forward" direction.
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M
        
        # Ograniczenie wag normą wektora
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)

        mlp[-1].deltas = y - batch_labels
        # Inicjalizujemy deltas -> różnica między tym co wyszło w sieci a tym co miało wyjść.
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")

        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for layer_idx in range(len(dbn)):
        mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1]) # cut biases

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 2.29s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.75s, accuracy: 36.89
# Epoch 3:	########################################	elapsed: 2.04s, accuracy: 65.27
# Epoch 4:	########################################	elapsed: 1.98s, accuracy: 74.90
# Epoch 5:	########################################	elapsed: 2.03s, accuracy: 80.88
# Epoch 6:	########################################	elapsed: 1.80s, accuracy: 90.15
# Epoch 7:	########################################	elapsed: 1.91s, accuracy: 92.80
# Epoch 8:	########################################	elapsed: 1.74s, accuracy: 93.71
# Epoch 9:	########################################	elapsed: 2.07s, accuracy: 93.32
# Epoch 10:	########################################	elapsed: 2.09s, accuracy: 94.76
# Epoch 11:	########################################	elapsed: 1.97s, accuracy: 93.78
# Epoch 12:	########################################	elapsed: 1.75s, accuracy: 94.16
# Epoch 13:	########################################	elapsed: 2.04s, accuracy: 94.55
# Epoch 14:	########################################	elapsed: 2.08s, accuracy: 95.57
# Epoch 15:	########################################	elapsed: 1.09s, accuracy: 94.93
# Epoch 16:	########################################	elapsed: 1.87s, accuracy: 95.57
# Epoch 17:	########################################	elapsed: 2.22s, accuracy: 95.56
# Epoch 18:	########################################	elapsed: 1.81s, accuracy: 95.94
# Epoch 19:	########################################	elapsed: 1.50s, accuracy: 96.09
# Epoch 20:	########################################	elapsed: 1.62s, accuracy: 96.07
# Epoch 21:	########################################	elapsed: 1.05s, accuracy: 96.55
# Epoch 22:	########################################	elapsed: 1.38s, accuracy: 96.64
# Epoch 23:	########################################	elapsed: 1.21s, accuracy: 96.73
# Epoch 24:	########################################	elapsed: 1.71s, accuracy: 96.76
# Epoch 25:	########################################	elapsed: 1.08s, accuracy: 96.78
# Epoch 26:	########################################	elapsed: 1.78s, accuracy: 96.71
# Epoch 27:	########################################	elapsed: 1.15s, accuracy: 96.70
# Epoch 28:	########################################	elapsed: 1.04s, accuracy: 96.69
# Epoch 29:	########################################	elapsed: 1.06s, accuracy: 96.69
# Epoch 30:	########################################	elapsed: 1.11s, accuracy: 96.69
# Epoch 31:	########################################	elapsed: 1.06s, accuracy: 96.70
# Epoch 32:	########################################	elapsed: 1.07s, accuracy: 96.71
# Epoch 33:	########################################	elapsed: 1.07s, accuracy: 96.71
# Epoch 34:	########################################	elapsed: 2.26s, accuracy: 96.74
# Epoch 35:	########################################	elapsed: 1.12s, accuracy: 96.74
# Epoch 36:	########################################	elapsed: 1.06s, accuracy: 96.74
# Epoch 37:	########################################	elapsed: 1.17s, accuracy: 96.74
# Epoch 38:	########################################	elapsed: 1.74s, accuracy: 96.75
# Epoch 39:	########################################	elapsed: 1.97s, accuracy: 96.74
# Epoch 40:	########################################	elapsed: 2.05s, accuracy: 96.74
# Epoch 41:	########################################	elapsed: 1.72s, accuracy: 96.75
# Epoch 42:	########################################	elapsed: 1.20s, accuracy: 96.74
# Epoch 43:	########################################	elapsed: 1.55s, accuracy: 96.73
# Epoch 44:	########################################	elapsed: 1.47s, accuracy: 96.73
# Epoch 45:	########################################	elapsed: 1.15s, accuracy: 96.73
# Epoch 46:	########################################	elapsed: 1.99s, accuracy: 96.73
# Epoch 47:	########################################	elapsed: 1.16s, accuracy: 96.73
# Epoch 48:	########################################	elapsed: 0.99s, accuracy: 96.73
# Epoch 49:	########################################	elapsed: 1.01s, accuracy: 96.72
# Epoch 50:	########################################	elapsed: 2.04s, accuracy: 96.72
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.90
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.70s, reconstruction error: 77.63
# Epoch 2:	########################################	elapsed: 1.73s, reconstruction error: 54.80
# Epoch 3:	########################################	elapsed: 1.64s, reconstruction error: 42.74
# Epoch 4:	########################################	elapsed: 1.64s, reconstruction error: 36.51
# Epoch 5:	########################################	elapsed: 1.43s, reconstruction error: 33.23
# Epoch 6:	########################################	elapsed: 1.25s, reconstruction error: 27.01
# Epoch 7:	########################################	elapsed: 1.57s, reconstruction error: 23.96
# Epoch 8:	########################################	elapsed: 1.70s, reconstruction error: 21.91
# Epoch 9:	########################################	elapsed: 1.65s, reconstruction error: 20.70
# Epoch 10:	########################################	elapsed: 1.67s, reconstruction error: 19.34
# Epoch 11:	########################################	elapsed: 1.73s, reconstruction error: 19.16
# Epoch 12:	########################################	elapsed: 1.64s, reconstruction error: 18.37
# Epoch 13:	########################################	elapsed: 1.00s, reconstruction error: 17.72
# Epoch 14:	########################################	elapsed: 1.08s, reconstruction error: 17.64
# Epoch 15:	########################################	elapsed: 1.19s, reconstruction error: 17.24
# Epoch 16:	########################################	elapsed: 1.76s, reconstruction error: 16.96
# Epoch 17:	########################################	elapsed: 1.23s, reconstruction error: 16.61
# Epoch 18:	########################################	elapsed: 1.24s, reconstruction error: 16.43
# Epoch 19:	########################################	elapsed: 1.60s, reconstruction error: 16.39
# Epoch 20:	########################################	elapsed: 1.39s, reconstruction error: 16.11
# Epoch 21:	########################################	elapsed: 1.56s, reconstruction error: 15.94
# Epoch 22:	########################################	elapsed: 1.48s, reconstruction error: 15.79
# Epoch 23:	########################################	elapsed: 1.93s, reconstruction error: 15.89
# Epoch 24:	########################################	elapsed: 1.56s, reconstruction error: 15.61
# Epoch 25:	########################################	elapsed: 1.97s, reconstruction error: 15.44
# Epoch 26:	########################################	elapsed: 1.97s, reconstruction error: 15.49
# Epoch 27:	########################################	elapsed: 2.02s, reconstruction error: 15.46
# Epoch 28:	########################################	elapsed: 1.96s, reconstruction error: 15.36
# Epoch 29:	########################################	elapsed: 1.79s, reconstruction error: 15.22
# Epoch 30:	########################################	elapsed: 1.43s, reconstruction error: 15.11
# Epoch 31:	########################################	elapsed: 1.92s, reconstruction error: 15.00
# Epoch 32:	########################################	elapsed: 1.81s, reconstruction error: 14.95
# Epoch 33:	########################################	elapsed: 1.92s, reconstruction error: 14.95
# Epoch 34:	########################################	elapsed: 1.42s, reconstruction error: 15.12
# Epoch 35:	########################################	elapsed: 1.45s, reconstruction error: 14.89
# Epoch 36:	########################################	elapsed: 1.94s, reconstruction error: 15.02
# Epoch 37:	########################################	elapsed: 1.09s, reconstruction error: 14.97
# Epoch 38:	########################################	elapsed: 1.25s, reconstruction error: 14.75
# Epoch 39:	########################################	elapsed: 1.82s, reconstruction error: 14.88
# Epoch 40:	########################################	elapsed: 1.39s, reconstruction error: 14.72
# Epoch 41:	########################################	elapsed: 1.39s, reconstruction error: 15.00
# Epoch 42:	########################################	elapsed: 1.59s, reconstruction error: 14.55
# Epoch 43:	########################################	elapsed: 1.90s, reconstruction error: 15.02
# Epoch 44:	########################################	elapsed: 1.53s, reconstruction error: 14.77
# Epoch 45:	########################################	elapsed: 1.09s, reconstruction error: 14.79
# Epoch 46:	########################################	elapsed: 1.33s, reconstruction error: 14.80
# Epoch 47:	########################################	elapsed: 1.09s, reconstruction error: 14.43
# Epoch 48:	########################################	elapsed: 1.05s, reconstruction error: 14.37
# Epoch 49:	########################################	elapsed: 1.07s, reconstruction error: 14.58
# Epoch 50:	########################################	elapsed: 1.05s, reconstruction error: 14.45
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.82s, reconstruction error: 15.70
# Epoch 2:	########################################	elapsed: 0.80s, reconstruction error: 11.62
# Epoch 3:	########################################	elapsed: 0.91s, reconstruction error: 9.30
# Epoch 4:	########################################	elapsed: 1.30s, reconstruction error: 8.12
# Epoch 5:	########################################	elapsed: 1.28s, reconstruction error: 7.49
# Epoch 6:	########################################	elapsed: 1.35s, reconstruction error: 6.24
# Epoch 7:	########################################	elapsed: 1.35s, reconstruction error: 5.54
# Epoch 8:	########################################	elapsed: 1.50s, reconstruction error: 5.34
# Epoch 9:	########################################	elapsed: 0.92s, reconstruction error: 5.18
# Epoch 10:	########################################	elapsed: 0.89s, reconstruction error: 5.17
# Epoch 11:	########################################	elapsed: 1.55s, reconstruction error: 5.09
# Epoch 12:	########################################	elapsed: 1.07s, reconstruction error: 5.32
# Epoch 13:	########################################	elapsed: 0.80s, reconstruction error: 5.22
# Epoch 14:	########################################	elapsed: 1.30s, reconstruction error: 5.23
# Epoch 15:	########################################	elapsed: 1.20s, reconstruction error: 5.15
# Epoch 16:	########################################	elapsed: 1.58s, reconstruction error: 5.18
# Epoch 17:	########################################	elapsed: 0.72s, reconstruction error: 5.18
# Epoch 18:	########################################	elapsed: 0.95s, reconstruction error: 5.31
# Epoch 19:	########################################	elapsed: 1.56s, reconstruction error: 5.36
# Epoch 20:	########################################	elapsed: 0.94s, reconstruction error: 5.40
# Epoch 21:	########################################	elapsed: 1.56s, reconstruction error: 5.27
# Epoch 22:	########################################	elapsed: 1.12s, reconstruction error: 5.45
# Epoch 23:	########################################	elapsed: 0.77s, reconstruction error: 5.63
# Epoch 24:	########################################	elapsed: 1.17s, reconstruction error: 5.42
# Epoch 25:	########################################	elapsed: 1.52s, reconstruction error: 5.63
# Epoch 26:	########################################	elapsed: 0.94s, reconstruction error: 5.48
# Epoch 27:	########################################	elapsed: 1.18s, reconstruction error: 5.59
# Epoch 28:	########################################	elapsed: 1.37s, reconstruction error: 5.85
# Epoch 29:	########################################	elapsed: 1.13s, reconstruction error: 5.90
# Epoch 30:	########################################	elapsed: 0.78s, reconstruction error: 5.63
# Epoch 31:	########################################	elapsed: 0.98s, reconstruction error: 5.73
# Epoch 32:	########################################	elapsed: 0.86s, reconstruction error: 5.83
# Epoch 33:	########################################	elapsed: 0.80s, reconstruction error: 5.71
# Epoch 34:	########################################	elapsed: 1.19s, reconstruction error: 5.69
# Epoch 35:	########################################	elapsed: 0.78s, reconstruction error: 5.72
# Epoch 36:	########################################	elapsed: 0.97s, reconstruction error: 5.78
# Epoch 37:	########################################	elapsed: 1.48s, reconstruction error: 5.90
# Epoch 38:	########################################	elapsed: 1.34s, reconstruction error: 5.87
# Epoch 39:	########################################	elapsed: 0.88s, reconstruction error: 6.00
# Epoch 40:	########################################	elapsed: 1.06s, reconstruction error: 5.93
# Epoch 41:	########################################	elapsed: 1.63s, reconstruction error: 5.85
# Epoch 42:	########################################	elapsed: 1.27s, reconstruction error: 5.87
# Epoch 43:	########################################	elapsed: 1.10s, reconstruction error: 5.88
# Epoch 44:	########################################	elapsed: 1.13s, reconstruction error: 5.97
# Epoch 45:	########################################	elapsed: 1.28s, reconstruction error: 6.11
# Epoch 46:	########################################	elapsed: 1.15s, reconstruction error: 6.01
# Epoch 47:	########################################	elapsed: 1.00s, reconstruction error: 5.92
# Epoch 48:	########################################	elapsed: 0.94s, reconstruction error: 6.20
# Epoch 49:	########################################	elapsed: 1.30s, reconstruction error: 6.04
# Epoch 50:	########################################	elapsed: 1.39s, reconstruction error: 6.00
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.88s, accuracy: 94.59
# Epoch 2:	########################################	elapsed: 1.84s, accuracy: 96.28
# Epoch 3:	########################################	elapsed: 1.87s, accuracy: 96.27
# Epoch 4:	########################################	elapsed: 2.12s, accuracy: 96.47
# Epoch 5:	########################################	elapsed: 1.77s, accuracy: 96.67
# Epoch 6:	########################################	elapsed: 1.33s, accuracy: 96.80
# Epoch 7:	########################################	elapsed: 1.44s, accuracy: 97.03
# Epoch 8:	########################################	elapsed: 1.23s, accuracy: 97.10
# Epoch 9:	########################################	elapsed: 1.40s, accuracy: 97.29
# Epoch 10:	########################################	elapsed: 1.71s, accuracy: 97.37
# Epoch 11:	########################################	elapsed: 1.23s, accuracy: 97.37
# Epoch 12:	########################################	elapsed: 2.13s, accuracy: 97.44
# Epoch 13:	########################################	elapsed: 1.52s, accuracy: 97.37
# Epoch 14:	########################################	elapsed: 2.08s, accuracy: 97.37
# Epoch 15:	########################################	elapsed: 2.09s, accuracy: 97.35
# Epoch 16:	########################################	elapsed: 2.08s, accuracy: 97.38
# Epoch 17:	########################################	elapsed: 2.04s, accuracy: 97.38
# Epoch 18:	########################################	elapsed: 1.43s, accuracy: 97.37
# Epoch 19:	########################################	elapsed: 1.19s, accuracy: 97.37
# Epoch 20:	########################################	elapsed: 2.08s, accuracy: 97.38
# Epoch 21:	########################################	elapsed: 1.86s, accuracy: 97.40
# Epoch 22:	########################################	elapsed: 1.81s, accuracy: 97.41
# Epoch 23:	########################################	elapsed: 2.03s, accuracy: 97.40
# Epoch 24:	########################################	elapsed: 1.92s, accuracy: 97.41
# Epoch 25:	########################################	elapsed: 1.89s, accuracy: 97.42
# Epoch 26:	########################################	elapsed: 1.91s, accuracy: 97.41
# Epoch 27:	########################################	elapsed: 1.87s, accuracy: 97.39
# Epoch 28:	########################################	elapsed: 1.79s, accuracy: 97.39
# Epoch 29:	########################################	elapsed: 1.38s, accuracy: 97.40
# Epoch 30:	########################################	elapsed: 1.98s, accuracy: 97.41
# Epoch 31:	########################################	elapsed: 2.18s, accuracy: 97.42
# Epoch 32:	########################################	elapsed: 2.14s, accuracy: 97.42
# Epoch 33:	########################################	elapsed: 1.70s, accuracy: 97.42
# Epoch 34:	########################################	elapsed: 1.34s, accuracy: 97.42
# Epoch 35:	########################################	elapsed: 1.81s, accuracy: 97.42
# Epoch 36:	########################################	elapsed: 2.13s, accuracy: 97.42
# Epoch 37:	########################################	elapsed: 1.58s, accuracy: 97.42
# Epoch 38:	########################################	elapsed: 1.16s, accuracy: 97.40
# Epoch 39:	########################################	elapsed: 1.79s, accuracy: 97.41
# Epoch 40:	########################################	elapsed: 2.17s, accuracy: 97.40
# Epoch 41:	########################################	elapsed: 1.73s, accuracy: 97.40
# Epoch 42:	########################################	elapsed: 1.07s, accuracy: 97.40
# Epoch 43:	########################################	elapsed: 1.29s, accuracy: 97.39
# Epoch 44:	########################################	elapsed: 1.08s, accuracy: 97.38
# Epoch 45:	########################################	elapsed: 2.20s, accuracy: 97.38
# Epoch 46:	########################################	elapsed: 1.28s, accuracy: 97.38
# Epoch 47:	########################################	elapsed: 2.13s, accuracy: 97.39
# Epoch 48:	########################################	elapsed: 1.07s, accuracy: 97.38
# Epoch 49:	########################################	elapsed: 1.06s, accuracy: 97.39
# Epoch 50:	########################################	elapsed: 1.03s, accuracy: 97.39
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.16s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.16s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.18s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.16s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 1.16s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 1.15s, accuracy: 40.61
# Epoch 7:	########################################	elapsed: 1.19s, accuracy: 82.61
# Epoch 8:	########################################	elapsed: 1.23s, accuracy: 90.17
# Epoch 9:	########################################	elapsed: 1.40s, accuracy: 91.77
# Epoch 10:	########################################	elapsed: 1.40s, accuracy: 93.14
# Epoch 11:	########################################	elapsed: 1.23s, accuracy: 93.53
# Epoch 12:	########################################	elapsed: 1.18s, accuracy: 93.98
# Epoch 13:	########################################	elapsed: 1.16s, accuracy: 93.43
# Epoch 14:	########################################	elapsed: 1.16s, accuracy: 94.09
# Epoch 15:	########################################	elapsed: 1.25s, accuracy: 92.43
# Epoch 16:	########################################	elapsed: 1.26s, accuracy: 94.37
# Epoch 17:	########################################	elapsed: 1.24s, accuracy: 95.49
# Epoch 18:	########################################	elapsed: 1.24s, accuracy: 94.29
# Epoch 19:	########################################	elapsed: 1.16s, accuracy: 94.97
# Epoch 20:	########################################	elapsed: 1.15s, accuracy: 95.64
# Epoch 21:	########################################	elapsed: 1.17s, accuracy: 95.59
# Epoch 22:	########################################	elapsed: 1.19s, accuracy: 95.59
# Epoch 23:	########################################	elapsed: 1.39s, accuracy: 96.04
# Epoch 24:	########################################	elapsed: 1.29s, accuracy: 96.01
# Epoch 25:	########################################	elapsed: 1.16s, accuracy: 96.13
# Epoch 26:	########################################	elapsed: 1.15s, accuracy: 96.35
# Epoch 27:	########################################	elapsed: 1.14s, accuracy: 96.31
# Epoch 28:	########################################	elapsed: 1.13s, accuracy: 96.20
# Epoch 29:	########################################	elapsed: 1.15s, accuracy: 96.23
# Epoch 30:	########################################	elapsed: 1.15s, accuracy: 96.37
# Epoch 31:	########################################	elapsed: 1.13s, accuracy: 96.43
# Epoch 32:	########################################	elapsed: 1.14s, accuracy: 96.45
# Epoch 33:	########################################	elapsed: 1.14s, accuracy: 96.48
# Epoch 34:	########################################	elapsed: 1.15s, accuracy: 96.49
# Epoch 35:	########################################	elapsed: 1.24s, accuracy: 96.48
# Epoch 36:	########################################	elapsed: 1.19s, accuracy: 96.47
# Epoch 37:	########################################	elapsed: 1.23s, accuracy: 96.48
# Epoch 38:	########################################	elapsed: 1.28s, accuracy: 96.49
# Epoch 39:	########################################	elapsed: 1.32s, accuracy: 96.49
# Epoch 40:	########################################	elapsed: 1.12s, accuracy: 96.50
# Epoch 41:	########################################	elapsed: 1.13s, accuracy: 96.49
# Epoch 42:	########################################	elapsed: 1.20s, accuracy: 96.50
# Epoch 43:	########################################	elapsed: 1.14s, accuracy: 96.49
# Epoch 44:	########################################	elapsed: 1.17s, accuracy: 96.49
# Epoch 45:	########################################	elapsed: 1.13s, accuracy: 96.49
# Epoch 46:	########################################	elapsed: 1.15s, accuracy: 96.49
# Epoch 47:	########################################	elapsed: 1.14s, accuracy: 96.49
# Epoch 48:	########################################	elapsed: 1.14s, accuracy: 96.49
# Epoch 49:	########################################	elapsed: 1.13s, accuracy: 96.50
# Epoch 50:	########################################	elapsed: 1.12s, accuracy: 96.51
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.72
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.56s, reconstruction error: 77.33
# Epoch 2:	########################################	elapsed: 0.55s, reconstruction error: 55.05
# Epoch 3:	########################################	elapsed: 0.57s, reconstruction error: 42.52
# Epoch 4:	########################################	elapsed: 0.56s, reconstruction error: 36.67
# Epoch 5:	########################################	elapsed: 0.56s, reconstruction error: 33.56
# Epoch 6:	########################################	elapsed: 0.58s, reconstruction error: 27.31
# Epoch 7:	########################################	elapsed: 0.62s, reconstruction error: 24.18
# Epoch 8:	########################################	elapsed: 0.58s, reconstruction error: 22.40
# Epoch 9:	########################################	elapsed: 0.56s, reconstruction error: 21.19
# Epoch 10:	########################################	elapsed: 0.56s, reconstruction error: 20.26
# Epoch 11:	########################################	elapsed: 0.63s, reconstruction error: 19.53
# Epoch 12:	########################################	elapsed: 0.58s, reconstruction error: 18.79
# Epoch 13:	########################################	elapsed: 0.58s, reconstruction error: 18.35
# Epoch 14:	########################################	elapsed: 0.57s, reconstruction error: 18.10
# Epoch 15:	########################################	elapsed: 0.57s, reconstruction error: 17.52
# Epoch 16:	########################################	elapsed: 0.57s, reconstruction error: 17.31
# Epoch 17:	########################################	elapsed: 0.58s, reconstruction error: 16.70
# Epoch 18:	########################################	elapsed: 0.58s, reconstruction error: 16.55
# Epoch 19:	########################################	elapsed: 0.58s, reconstruction error: 16.36
# Epoch 20:	########################################	elapsed: 0.58s, reconstruction error: 16.54
# Epoch 21:	########################################	elapsed: 0.59s, reconstruction error: 16.20
# Epoch 22:	########################################	elapsed: 0.64s, reconstruction error: 16.22
# Epoch 23:	########################################	elapsed: 0.66s, reconstruction error: 15.77
# Epoch 24:	########################################	elapsed: 0.65s, reconstruction error: 15.97
# Epoch 25:	########################################	elapsed: 0.60s, reconstruction error: 15.62
# Epoch 26:	########################################	elapsed: 0.65s, reconstruction error: 15.62
# Epoch 27:	########################################	elapsed: 0.62s, reconstruction error: 15.38
# Epoch 28:	########################################	elapsed: 0.63s, reconstruction error: 15.35
# Epoch 29:	########################################	elapsed: 0.62s, reconstruction error: 15.38
# Epoch 30:	########################################	elapsed: 0.61s, reconstruction error: 15.44
# Epoch 31:	########################################	elapsed: 0.64s, reconstruction error: 15.20
# Epoch 32:	########################################	elapsed: 0.69s, reconstruction error: 15.26
# Epoch 33:	########################################	elapsed: 0.74s, reconstruction error: 15.12
# Epoch 34:	########################################	elapsed: 0.78s, reconstruction error: 15.09
# Epoch 35:	########################################	elapsed: 0.90s, reconstruction error: 14.89
# Epoch 36:	########################################	elapsed: 0.87s, reconstruction error: 14.93
# Epoch 37:	########################################	elapsed: 0.86s, reconstruction error: 14.73
# Epoch 38:	########################################	elapsed: 0.87s, reconstruction error: 14.94
# Epoch 39:	########################################	elapsed: 0.86s, reconstruction error: 15.08
# Epoch 40:	########################################	elapsed: 0.78s, reconstruction error: 14.80
# Epoch 41:	########################################	elapsed: 0.76s, reconstruction error: 14.81
# Epoch 42:	########################################	elapsed: 0.86s, reconstruction error: 14.79
# Epoch 43:	########################################	elapsed: 0.67s, reconstruction error: 14.61
# Epoch 44:	########################################	elapsed: 0.67s, reconstruction error: 14.71
# Epoch 45:	########################################	elapsed: 0.67s, reconstruction error: 14.49
# Epoch 46:	########################################	elapsed: 0.70s, reconstruction error: 14.70
# Epoch 47:	########################################	elapsed: 0.66s, reconstruction error: 14.67
# Epoch 48:	########################################	elapsed: 0.63s, reconstruction error: 14.57
# Epoch 49:	########################################	elapsed: 0.62s, reconstruction error: 14.53
# Epoch 50:	########################################	elapsed: 0.63s, reconstruction error: 14.46
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.54s, reconstruction error: 15.31
# Epoch 2:	########################################	elapsed: 0.54s, reconstruction error: 11.36
# Epoch 3:	########################################	elapsed: 0.54s, reconstruction error: 8.98
# Epoch 4:	########################################	elapsed: 0.55s, reconstruction error: 7.93
# Epoch 5:	########################################	elapsed: 0.53s, reconstruction error: 7.34
# Epoch 6:	########################################	elapsed: 0.55s, reconstruction error: 6.04
# Epoch 7:	########################################	elapsed: 0.54s, reconstruction error: 5.31
# Epoch 8:	########################################	elapsed: 0.57s, reconstruction error: 5.15
# Epoch 9:	########################################	elapsed: 0.57s, reconstruction error: 4.97
# Epoch 10:	########################################	elapsed: 0.56s, reconstruction error: 4.98
# Epoch 11:	########################################	elapsed: 0.56s, reconstruction error: 4.95
# Epoch 12:	########################################	elapsed: 0.56s, reconstruction error: 4.96
# Epoch 13:	########################################	elapsed: 0.54s, reconstruction error: 4.87
# Epoch 14:	########################################	elapsed: 0.53s, reconstruction error: 5.03
# Epoch 15:	########################################	elapsed: 0.54s, reconstruction error: 5.04
# Epoch 16:	########################################	elapsed: 0.59s, reconstruction error: 5.04
# Epoch 17:	########################################	elapsed: 0.62s, reconstruction error: 5.07
# Epoch 18:	########################################	elapsed: 0.62s, reconstruction error: 5.19
# Epoch 19:	########################################	elapsed: 0.62s, reconstruction error: 5.15
# Epoch 20:	########################################	elapsed: 0.61s, reconstruction error: 5.17
# Epoch 21:	########################################	elapsed: 0.57s, reconstruction error: 5.08
# Epoch 22:	########################################	elapsed: 0.53s, reconstruction error: 5.10
# Epoch 23:	########################################	elapsed: 0.53s, reconstruction error: 5.24
# Epoch 24:	########################################	elapsed: 0.53s, reconstruction error: 5.47
# Epoch 25:	########################################	elapsed: 0.60s, reconstruction error: 5.37
# Epoch 26:	########################################	elapsed: 0.61s, reconstruction error: 5.37
# Epoch 27:	########################################	elapsed: 0.57s, reconstruction error: 5.37
# Epoch 28:	########################################	elapsed: 0.59s, reconstruction error: 5.43
# Epoch 29:	########################################	elapsed: 0.58s, reconstruction error: 5.40
# Epoch 30:	########################################	elapsed: 0.56s, reconstruction error: 5.36
# Epoch 31:	########################################	elapsed: 0.53s, reconstruction error: 5.56
# Epoch 32:	########################################	elapsed: 0.53s, reconstruction error: 5.37
# Epoch 33:	########################################	elapsed: 0.54s, reconstruction error: 5.58
# Epoch 34:	########################################	elapsed: 0.56s, reconstruction error: 5.49
# Epoch 35:	########################################	elapsed: 0.56s, reconstruction error: 5.49
# Epoch 36:	########################################	elapsed: 0.54s, reconstruction error: 5.59
# Epoch 37:	########################################	elapsed: 0.53s, reconstruction error: 5.70
# Epoch 38:	########################################	elapsed: 0.53s, reconstruction error: 5.63
# Epoch 39:	########################################	elapsed: 0.52s, reconstruction error: 5.65
# Epoch 40:	########################################	elapsed: 0.52s, reconstruction error: 5.78
# Epoch 41:	########################################	elapsed: 0.53s, reconstruction error: 5.62
# Epoch 42:	########################################	elapsed: 0.54s, reconstruction error: 5.79
# Epoch 43:	########################################	elapsed: 0.55s, reconstruction error: 5.71
# Epoch 44:	########################################	elapsed: 0.53s, reconstruction error: 5.58
# Epoch 45:	########################################	elapsed: 0.53s, reconstruction error: 5.66
# Epoch 46:	########################################	elapsed: 0.54s, reconstruction error: 5.84
# Epoch 47:	########################################	elapsed: 0.53s, reconstruction error: 5.70
# Epoch 48:	########################################	elapsed: 0.53s, reconstruction error: 5.74
# Epoch 49:	########################################	elapsed: 0.55s, reconstruction error: 5.71
# Epoch 50:	########################################	elapsed: 0.62s, reconstruction error: 5.98
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.80s, reconstruction error: 2.17
# Epoch 2:	########################################	elapsed: 0.75s, reconstruction error: 2.10
# Epoch 3:	########################################	elapsed: 0.72s, reconstruction error: 2.00
# Epoch 4:	########################################	elapsed: 0.74s, reconstruction error: 1.87
# Epoch 5:	########################################	elapsed: 0.84s, reconstruction error: 1.68
# Epoch 6:	########################################	elapsed: 0.74s, reconstruction error: 1.15
# Epoch 7:	########################################	elapsed: 0.74s, reconstruction error: 0.87
# Epoch 8:	########################################	elapsed: 0.74s, reconstruction error: 0.75
# Epoch 9:	########################################	elapsed: 0.73s, reconstruction error: 0.68
# Epoch 10:	########################################	elapsed: 0.74s, reconstruction error: 0.63
# Epoch 11:	########################################	elapsed: 0.74s, reconstruction error: 0.59
# Epoch 12:	########################################	elapsed: 0.75s, reconstruction error: 0.55
# Epoch 13:	########################################	elapsed: 0.74s, reconstruction error: 0.52
# Epoch 14:	########################################	elapsed: 0.75s, reconstruction error: 0.50
# Epoch 15:	########################################	elapsed: 0.74s, reconstruction error: 0.48
# Epoch 16:	########################################	elapsed: 0.73s, reconstruction error: 0.47
# Epoch 17:	########################################	elapsed: 0.73s, reconstruction error: 0.44
# Epoch 18:	########################################	elapsed: 0.74s, reconstruction error: 0.44
# Epoch 19:	########################################	elapsed: 0.74s, reconstruction error: 0.43
# Epoch 20:	########################################	elapsed: 0.73s, reconstruction error: 0.41
# Epoch 21:	########################################	elapsed: 0.74s, reconstruction error: 0.40
# Epoch 22:	########################################	elapsed: 0.74s, reconstruction error: 0.39
# Epoch 23:	########################################	elapsed: 0.74s, reconstruction error: 0.38
# Epoch 24:	########################################	elapsed: 0.74s, reconstruction error: 0.37
# Epoch 25:	########################################	elapsed: 0.74s, reconstruction error: 0.37
# Epoch 26:	########################################	elapsed: 0.74s, reconstruction error: 0.36
# Epoch 27:	########################################	elapsed: 0.77s, reconstruction error: 0.35
# Epoch 28:	########################################	elapsed: 0.77s, reconstruction error: 0.36
# Epoch 29:	########################################	elapsed: 0.75s, reconstruction error: 0.35
# Epoch 30:	########################################	elapsed: 0.76s, reconstruction error: 0.34
# Epoch 31:	########################################	elapsed: 0.76s, reconstruction error: 0.34
# Epoch 32:	########################################	elapsed: 0.75s, reconstruction error: 0.34
# Epoch 33:	########################################	elapsed: 0.75s, reconstruction error: 0.33
# Epoch 34:	########################################	elapsed: 0.75s, reconstruction error: 0.33
# Epoch 35:	########################################	elapsed: 0.75s, reconstruction error: 0.33
# Epoch 36:	########################################	elapsed: 0.74s, reconstruction error: 0.33
# Epoch 37:	########################################	elapsed: 0.74s, reconstruction error: 0.33
# Epoch 38:	########################################	elapsed: 0.74s, reconstruction error: 0.32
# Epoch 39:	########################################	elapsed: 0.74s, reconstruction error: 0.32
# Epoch 40:	########################################	elapsed: 0.74s, reconstruction error: 0.32
# Epoch 41:	########################################	elapsed: 0.75s, reconstruction error: 0.32
# Epoch 42:	########################################	elapsed: 0.75s, reconstruction error: 0.32
# Epoch 43:	########################################	elapsed: 0.75s, reconstruction error: 0.33
# Epoch 44:	########################################	elapsed: 0.75s, reconstruction error: 0.31
# Epoch 45:	########################################	elapsed: 0.76s, reconstruction error: 0.31
# Epoch 46:	########################################	elapsed: 0.76s, reconstruction error: 0.32
# Epoch 47:	########################################	elapsed: 0.76s, reconstruction error: 0.32
# Epoch 48:	########################################	elapsed: 0.84s, reconstruction error: 0.31
# Epoch 49:	########################################	elapsed: 0.79s, reconstruction error: 0.31
# Epoch 50:	########################################	elapsed: 0.78s, reconstruction error: 0.31
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.29s, accuracy: 94.86
# Epoch 2:	########################################	elapsed: 1.21s, accuracy: 94.92
# Epoch 3:	########################################	elapsed: 1.17s, accuracy: 96.20
# Epoch 4:	########################################	elapsed: 1.17s, accuracy: 96.50
# Epoch 5:	########################################	elapsed: 1.18s, accuracy: 96.35
# Epoch 6:	########################################	elapsed: 1.14s, accuracy: 96.39
# Epoch 7:	########################################	elapsed: 1.14s, accuracy: 96.36
# Epoch 8:	########################################	elapsed: 1.14s, accuracy: 96.73
# Epoch 9:	########################################	elapsed: 1.14s, accuracy: 96.82
# Epoch 10:	########################################	elapsed: 1.15s, accuracy: 96.91
# Epoch 11:	########################################	elapsed: 1.14s, accuracy: 96.82
# Epoch 12:	########################################	elapsed: 1.14s, accuracy: 96.84
# Epoch 13:	########################################	elapsed: 1.14s, accuracy: 97.12
# Epoch 14:	########################################	elapsed: 1.14s, accuracy: 97.23
# Epoch 15:	########################################	elapsed: 1.15s, accuracy: 97.25
# Epoch 16:	########################################	elapsed: 1.14s, accuracy: 97.44
# Epoch 17:	########################################	elapsed: 1.18s, accuracy: 97.44
# Epoch 18:	########################################	elapsed: 1.21s, accuracy: 97.44
# Epoch 19:	########################################	elapsed: 1.29s, accuracy: 97.48
# Epoch 20:	########################################	elapsed: 1.28s, accuracy: 97.50
# Epoch 21:	########################################	elapsed: 1.39s, accuracy: 97.51
# Epoch 22:	########################################	elapsed: 1.36s, accuracy: 97.51
# Epoch 23:	########################################	elapsed: 1.47s, accuracy: 97.51
# Epoch 24:	########################################	elapsed: 1.22s, accuracy: 97.52
# Epoch 25:	########################################	elapsed: 1.26s, accuracy: 97.50
# Epoch 26:	########################################	elapsed: 1.24s, accuracy: 97.50
# Epoch 27:	########################################	elapsed: 1.41s, accuracy: 97.50
# Epoch 28:	########################################	elapsed: 1.30s, accuracy: 97.50
# Epoch 29:	########################################	elapsed: 1.43s, accuracy: 97.49
# Epoch 30:	########################################	elapsed: 1.40s, accuracy: 97.50
# Epoch 31:	########################################	elapsed: 1.23s, accuracy: 97.50
# Epoch 32:	########################################	elapsed: 1.18s, accuracy: 97.50
# Epoch 33:	########################################	elapsed: 1.23s, accuracy: 97.50
# Epoch 34:	########################################	elapsed: 1.20s, accuracy: 97.50
# Epoch 35:	########################################	elapsed: 1.12s, accuracy: 97.50
# Epoch 36:	########################################	elapsed: 1.34s, accuracy: 97.50
# Epoch 37:	########################################	elapsed: 1.32s, accuracy: 97.50
# Epoch 38:	########################################	elapsed: 1.38s, accuracy: 97.51
# Epoch 39:	########################################	elapsed: 1.30s, accuracy: 97.51
# Epoch 40:	########################################	elapsed: 1.31s, accuracy: 97.50
# Epoch 41:	########################################	elapsed: 1.44s, accuracy: 97.50
# Epoch 42:	########################################	elapsed: 1.27s, accuracy: 97.50
# Epoch 43:	########################################	elapsed: 1.34s, accuracy: 97.50
# Epoch 44:	########################################	elapsed: 1.19s, accuracy: 97.49
# Epoch 45:	########################################	elapsed: 1.17s, accuracy: 97.49
# Epoch 46:	########################################	elapsed: 1.17s, accuracy: 97.49
# Epoch 47:	########################################	elapsed: 1.14s, accuracy: 97.49
# Epoch 48:	########################################	elapsed: 1.13s, accuracy: 97.49
# Epoch 49:	########################################	elapsed: 1.14s, accuracy: 97.49
# Epoch 50:	########################################	elapsed: 1.16s, accuracy: 97.50
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.90
# 	layer 4: 4.00
