# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    features_in_observation_count = minibatch.shape[1]

    positive_visible = minibatch
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # Positive Phase
    positive_hidden_preactivation = positive_visible @ rbm.W[:, :-1] # Slice-out bias for hidden layer
    positive_hidden[:, :-1] = sigmoid(positive_hidden_preactivation)
    positive_gradient = positive_visible.T @ positive_hidden / observations_count
    
    # Negative Phase
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(positive_hidden.shape[0],
                                                             positive_hidden.shape[1] - 1)
    
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                 negative_visible.shape[1] - 1)
    
    for _ in range(k-1):
          
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(negative_hidden.shape[0],
                                                                                   negative_hidden.shape[1] - 1)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                    negative_visible.shape[1] - 1)
    
    negative_hidden_preactivation = negative_visible @ rbm.W[:, :-1]
    negative_hidden[:, :-1] = sigmoid(negative_hidden_preactivation)
    negative_gradient = negative_visible.T @ negative_hidden / observations_count
    

    # UPDATE WEIGHTS AND UTILIZE MOMENTUM
    # rbm.M matrix should remebmer direction of gradient propagation in previous steps.
    # Macierz M ma pamiętać, kierunki w których poruszał się gradient w poprzednich krokach.
    # Algorytm z metodą momentum ma dużo szybciej zbiegać do prawidłowej wartości.

    gradient = - positive_gradient + negative_gradient
    momentum_from_previous_step = rbm.momentum * rbm.M
    rbm.M =  momentum_from_previous_step - rbm.learning_rate * gradient
    rbm.W += rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 1.10s, reconstruction error: 26.47
# Epoch 1:	#####################################################	elapsed: 1.12s, reconstruction error: 21.40
# Epoch 2:	#####################################################	elapsed: 0.96s, reconstruction error: 18.80
# Epoch 3:	#####################################################	elapsed: 1.61s, reconstruction error: 17.27
# Epoch 4:	#####################################################	elapsed: 1.07s, reconstruction error: 16.30
# Epoch 5:	#####################################################	elapsed: 1.34s, reconstruction error: 15.13
# Epoch 6:	#####################################################	elapsed: 1.16s, reconstruction error: 13.96
# Epoch 7:	#####################################################	elapsed: 1.65s, reconstruction error: 13.28
# Epoch 8:	#####################################################	elapsed: 1.08s, reconstruction error: 12.90
# Epoch 9:	#####################################################	elapsed: 1.13s, reconstruction error: 12.53
# Epoch 10:	#####################################################	elapsed: 1.22s, reconstruction error: 12.09
# Epoch 11:	#####################################################	elapsed: 1.43s, reconstruction error: 11.95
# Epoch 12:	#####################################################	elapsed: 0.97s, reconstruction error: 11.81
# Epoch 13:	#####################################################	elapsed: 1.57s, reconstruction error: 11.65
# Epoch 14:	#####################################################	elapsed: 1.23s, reconstruction error: 11.53
# Epoch 15:	#####################################################	elapsed: 1.12s, reconstruction error: 11.17
# Epoch 16:	#####################################################	elapsed: 1.41s, reconstruction error: 11.17
# Epoch 17:	#####################################################	elapsed: 1.14s, reconstruction error: 11.19
# Epoch 18:	#####################################################	elapsed: 1.08s, reconstruction error: 11.15
# Epoch 19:	#####################################################	elapsed: 1.22s, reconstruction error: 11.08
# Epoch 20:	#####################################################	elapsed: 1.28s, reconstruction error: 10.94
# Epoch 21:	#####################################################	elapsed: 1.17s, reconstruction error: 10.91
# Epoch 22:	#####################################################	elapsed: 1.15s, reconstruction error: 10.73
# Epoch 23:	#####################################################	elapsed: 1.03s, reconstruction error: 10.91
# Epoch 24:	#####################################################	elapsed: 1.12s, reconstruction error: 10.79
# Epoch 25:	#####################################################	elapsed: 0.97s, reconstruction error: 10.82
# Epoch 26:	#####################################################	elapsed: 0.98s, reconstruction error: 10.61
# Epoch 27:	#####################################################	elapsed: 1.01s, reconstruction error: 10.62
# Epoch 28:	#####################################################	elapsed: 1.13s, reconstruction error: 10.56
# Epoch 29:	#####################################################	elapsed: 1.07s, reconstruction error: 10.64
# Epoch 30:	#####################################################	elapsed: 0.99s, reconstruction error: 10.46
# Epoch 31:	#####################################################	elapsed: 1.39s, reconstruction error: 10.31
# Epoch 32:	#####################################################	elapsed: 1.60s, reconstruction error: 10.43
# Epoch 33:	#####################################################	elapsed: 1.15s, reconstruction error: 10.48
# Epoch 34:	#####################################################	elapsed: 1.36s, reconstruction error: 10.42
# Epoch 35:	#####################################################	elapsed: 1.24s, reconstruction error: 10.47
# Epoch 36:	#####################################################	elapsed: 1.17s, reconstruction error: 10.32
# Epoch 37:	#####################################################	elapsed: 1.30s, reconstruction error: 10.33
# Epoch 38:	#####################################################	elapsed: 1.41s, reconstruction error: 10.41
# Epoch 39:	#####################################################	elapsed: 1.58s, reconstruction error: 10.28
# Epoch 40:	###################################
# C:\Users\msmen\AppData\Local\Temp/ipykernel_23744/2956573362.py:2: RuntimeWarning: overflow encountered in exp
#   return 1.0 / (1.0 + np.exp(-matrix))
# ##################	elapsed: 2.44s, reconstruction error: 10.38
# Epoch 41:	#####################################################	elapsed: 1.47s, reconstruction error: 10.29
# Epoch 42:	#####################################################	elapsed: 2.24s, reconstruction error: 10.24
# Epoch 43:	#####################################################	elapsed: 1.93s, reconstruction error: 10.20
# Epoch 44:	#####################################################	elapsed: 1.54s, reconstruction error: 10.12
# Epoch 45:	#####################################################	elapsed: 1.08s, reconstruction error: 10.29
# Epoch 46:	#####################################################	elapsed: 1.51s, reconstruction error: 10.26
# Epoch 47:	#####################################################	elapsed: 1.14s, reconstruction error: 10.18
# Epoch 48:	#####################################################	elapsed: 1.00s, reconstruction error: 10.18
# Epoch 49:	#####################################################	elapsed: 1.49s, reconstruction error: 10.08
# Training finished!

# %%
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
draw_samples(rbm, monitoring_set[:10*24])

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    # dbn - lista kolejnych warstw, lista dbnów.
    # może być tak że będziemy przechodzić przez mniej warstw.
    # jeśli chcemy trenować warstwę 3 to propagujemy obserwacje przez losowe wagi dwóch pierwszy warstw
    # Zaczynamy od warstwy uczącej
    # jak zrobimy propagate przez całego DBN i dostaniemy ostatnią warstwę
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    minibatch_after_propagation = propagate_up(dbn, layers_count, minibatch)
    rbm = dbn[layers_count]

    return reconstuction_error(rbm, minibatch_after_propagation)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    # Wyciagnięcie fantazji z DBN
    # Jeśli zrobimy propagate up, wyciągniemy próbkę i propagate down przez wszystkie warstwy to dostaniemy fantazję DBNa.

    sample = propagate_up(dbn, layer_idx, minibatch)
    sample = sample_rbm(dbn[layer_idx], sample, steps) 
    sample = propagate_down(dbn, layer_idx, sample)
    
    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.91s, reconstruction error: 24.76
# Epoch 1:	#####################################################	elapsed: 1.80s, reconstruction error: 19.40
# Epoch 2:	#####################################################	elapsed: 1.72s, reconstruction error: 16.78
# Epoch 3:	#####################################################	elapsed: 1.81s, reconstruction error: 15.29
# Epoch 4:	#####################################################	elapsed: 1.73s, reconstruction error: 14.06
# Epoch 5:	#####################################################	elapsed: 1.80s, reconstruction error: 13.08
# Epoch 6:	#####################################################	elapsed: 1.87s, reconstruction error: 11.96
# Epoch 7:	#####################################################	elapsed: 1.83s, reconstruction error: 11.40
# Epoch 8:	#####################################################	elapsed: 1.90s, reconstruction error: 11.05
# Epoch 9:	#####################################################	elapsed: 1.62s, reconstruction error: 10.54
# Epoch 10:	#####################################################	elapsed: 1.74s, reconstruction error: 10.33
# Epoch 11:	#####################################################	elapsed: 1.59s, reconstruction error: 9.88
# Epoch 12:	#####################################################	elapsed: 1.64s, reconstruction error: 9.90
# Epoch 13:	#####################################################	elapsed: 1.51s, reconstruction error: 9.76
# Epoch 14:	#####################################################	elapsed: 1.58s, reconstruction error: 9.67
# Epoch 15:	#####################################################	elapsed: 1.73s, reconstruction error: 9.54
# Epoch 16:	#####################################################	elapsed: 1.76s, reconstruction error: 9.52
# Epoch 17:	#####################################################	elapsed: 2.35s, reconstruction error: 9.44
# Epoch 18:	#####################################################	elapsed: 2.18s, reconstruction error: 9.13
# Epoch 19:	#####################################################	elapsed: 1.80s, reconstruction error: 9.08
# Epoch 20:	#####################################################	elapsed: 1.74s, reconstruction error: 9.23
# Epoch 21:	#####################################################	elapsed: 1.81s, reconstruction error: 9.02
# Epoch 22:	#####################################################	elapsed: 1.66s, reconstruction error: 9.06
# Epoch 23:	#####################################################	elapsed: 1.73s, reconstruction error: 9.07
# Epoch 24:	#####################################################	elapsed: 1.84s, reconstruction error: 9.03
# Epoch 25:	#####################################################	elapsed: 1.69s, reconstruction error: 8.83
# Epoch 26:	#####################################################	elapsed: 1.78s, reconstruction error: 8.93
# Epoch 27:	#####################################################	elapsed: 1.93s, reconstruction error: 8.97
# Epoch 28:	#####################################################	elapsed: 1.79s, reconstruction error: 8.91
# Epoch 29:	#####################################################	elapsed: 1.77s, reconstruction error: 8.81
# Epoch 30:	#####################################################	elapsed: 1.93s, reconstruction error: 8.79
# Epoch 31:	#####################################################	elapsed: 1.65s, reconstruction error: 8.86
# Epoch 32:	#####################################################	elapsed: 1.60s, reconstruction error: 8.97
# Epoch 33:	#####################################################	elapsed: 1.57s, reconstruction error: 8.93
# Epoch 34:	#####################################################	elapsed: 1.64s, reconstruction error: 8.65
# Epoch 35:	#####################################################	elapsed: 1.83s, reconstruction error: 8.69
# Epoch 36:	#####################################################	elapsed: 1.58s, reconstruction error: 8.58
# Epoch 37:	#####################################################	elapsed: 1.82s, reconstruction error: 8.65
# Epoch 38:	#####################################################	elapsed: 1.78s, reconstruction error: 8.56
# Epoch 39:	#####################################################	elapsed: 2.01s, reconstruction error: 8.69
# Epoch 40:	#####################################################	elapsed: 2.01s, reconstruction error: 8.49
# Epoch 41:	#####################################################	elapsed: 1.92s, reconstruction error: 8.63
# Epoch 42:	#####################################################	elapsed: 1.64s, reconstruction error: 8.51
# Epoch 43:	#####################################################	elapsed: 2.00s, reconstruction error: 8.51
# Epoch 44:	#####################################################	elapsed: 2.00s, reconstruction error: 8.52
# Epoch 45:	#####################################################	elapsed: 1.71s, reconstruction error: 8.66
# Epoch 46:	#####################################################	elapsed: 1.76s, reconstruction error: 8.34
# Epoch 47:	#####################################################	elapsed: 1.74s, reconstruction error: 8.43
# Epoch 48:	#####################################################	elapsed: 1.96s, reconstruction error: 8.44
# Epoch 49:	#####################################################	elapsed: 1.68s, reconstruction error: 8.45
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.67s, reconstruction error: 14.37
# Epoch 1:	#####################################################	elapsed: 0.71s, reconstruction error: 10.94
# Epoch 2:	#####################################################	elapsed: 0.71s, reconstruction error: 9.25
# Epoch 3:	#####################################################	elapsed: 0.70s, reconstruction error: 8.24
# Epoch 4:	#####################################################	elapsed: 0.67s, reconstruction error: 7.63
# Epoch 5:	#####################################################	elapsed: 0.70s, reconstruction error: 7.02
# Epoch 6:	#####################################################	elapsed: 0.83s, reconstruction error: 6.51
# Epoch 7:	#####################################################	elapsed: 0.68s, reconstruction error: 6.08
# Epoch 8:	#####################################################	elapsed: 0.67s, reconstruction error: 5.75
# Epoch 9:	#####################################################	elapsed: 0.69s, reconstruction error: 5.58
# Epoch 10:	#####################################################	elapsed: 0.74s, reconstruction error: 5.32
# Epoch 11:	#####################################################	elapsed: 1.04s, reconstruction error: 5.18
# Epoch 12:	#####################################################	elapsed: 0.69s, reconstruction error: 5.08
# Epoch 13:	#####################################################	elapsed: 0.67s, reconstruction error: 4.92
# Epoch 14:	#####################################################	elapsed: 0.68s, reconstruction error: 4.88
# Epoch 15:	#####################################################	elapsed: 0.67s, reconstruction error: 4.81
# Epoch 16:	#####################################################	elapsed: 0.70s, reconstruction error: 4.72
# Epoch 17:	#####################################################	elapsed: 0.70s, reconstruction error: 4.72
# Epoch 18:	#####################################################	elapsed: 0.73s, reconstruction error: 4.62
# Epoch 19:	#####################################################	elapsed: 0.70s, reconstruction error: 4.55
# Epoch 20:	#####################################################	elapsed: 0.69s, reconstruction error: 4.44
# Epoch 21:	#####################################################	elapsed: 0.70s, reconstruction error: 4.39
# Epoch 22:	#####################################################	elapsed: 0.70s, reconstruction error: 4.48
# Epoch 23:	#####################################################	elapsed: 0.69s, reconstruction error: 4.50
# Epoch 24:	#####################################################	elapsed: 0.69s, reconstruction error: 4.47
# Epoch 25:	#####################################################	elapsed: 0.69s, reconstruction error: 4.52
# Epoch 26:	#####################################################	elapsed: 0.69s, reconstruction error: 4.42
# Epoch 27:	#####################################################	elapsed: 0.71s, reconstruction error: 4.29
# Epoch 28:	#####################################################	elapsed: 0.69s, reconstruction error: 4.38
# Epoch 29:	#####################################################	elapsed: 0.70s, reconstruction error: 4.28
# Epoch 30:	#####################################################	elapsed: 0.66s, reconstruction error: 4.26
# Epoch 31:	#####################################################	elapsed: 0.70s, reconstruction error: 4.27
# Epoch 32:	#####################################################	elapsed: 0.70s, reconstruction error: 4.20
# Epoch 33:	#####################################################	elapsed: 0.74s, reconstruction error: 4.27
# Epoch 34:	#####################################################	elapsed: 0.68s, reconstruction error: 4.23
# Epoch 35:	#####################################################	elapsed: 0.73s, reconstruction error: 4.34
# Epoch 36:	#####################################################	elapsed: 0.70s, reconstruction error: 4.23
# Epoch 37:	#####################################################	elapsed: 0.72s, reconstruction error: 4.16
# Epoch 38:	#####################################################	elapsed: 0.69s, reconstruction error: 4.15
# Epoch 39:	#####################################################	elapsed: 0.70s, reconstruction error: 4.12
# Epoch 40:	#####################################################	elapsed: 0.68s, reconstruction error: 4.23
# Epoch 41:	#####################################################	elapsed: 0.73s, reconstruction error: 4.13
# Epoch 42:	#####################################################	elapsed: 0.70s, reconstruction error: 4.20
# Epoch 43:	#####################################################	elapsed: 0.77s, reconstruction error: 4.17
# Epoch 44:	#####################################################	elapsed: 0.70s, reconstruction error: 4.17
# Epoch 45:	#####################################################	elapsed: 0.80s, reconstruction error: 4.26
# Epoch 46:	#####################################################	elapsed: 0.70s, reconstruction error: 4.19
# Epoch 47:	#####################################################	elapsed: 0.69s, reconstruction error: 4.11
# Epoch 48:	#####################################################	elapsed: 0.69s, reconstruction error: 4.13
# Epoch 49:	#####################################################	elapsed: 0.69s, reconstruction error: 4.09
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.76s, reconstruction error: 10.23
# Epoch 1:	#####################################################	elapsed: 0.77s, reconstruction error: 7.52
# Epoch 2:	#####################################################	elapsed: 0.74s, reconstruction error: 6.30
# Epoch 3:	#####################################################	elapsed: 0.76s, reconstruction error: 5.59
# Epoch 4:	#####################################################	elapsed: 0.77s, reconstruction error: 5.10
# Epoch 5:	#####################################################	elapsed: 0.76s, reconstruction error: 4.54
# Epoch 6:	#####################################################	elapsed: 0.76s, reconstruction error: 4.29
# Epoch 7:	#####################################################	elapsed: 0.75s, reconstruction error: 3.84
# Epoch 8:	#####################################################	elapsed: 0.76s, reconstruction error: 3.67
# Epoch 9:	#####################################################	elapsed: 0.77s, reconstruction error: 3.58
# Epoch 10:	#####################################################	elapsed: 0.78s, reconstruction error: 3.49
# Epoch 11:	#####################################################	elapsed: 0.75s, reconstruction error: 3.51
# Epoch 12:	#####################################################	elapsed: 0.88s, reconstruction error: 3.36
# Epoch 13:	#####################################################	elapsed: 0.75s, reconstruction error: 3.39
# Epoch 14:	#####################################################	elapsed: 0.76s, reconstruction error: 3.29
# Epoch 15:	#####################################################	elapsed: 0.75s, reconstruction error: 3.24
# Epoch 16:	#####################################################	elapsed: 0.76s, reconstruction error: 3.21
# Epoch 17:	#####################################################	elapsed: 0.75s, reconstruction error: 3.18
# Epoch 18:	#####################################################	elapsed: 0.83s, reconstruction error: 3.18
# Epoch 19:	#####################################################	elapsed: 0.75s, reconstruction error: 3.17
# Epoch 20:	#####################################################	elapsed: 0.79s, reconstruction error: 3.14
# Epoch 21:	#####################################################	elapsed: 0.75s, reconstruction error: 3.12
# Epoch 22:	#####################################################	elapsed: 0.78s, reconstruction error: 3.08
# Epoch 23:	#####################################################	elapsed: 0.77s, reconstruction error: 3.06
# Epoch 24:	#####################################################	elapsed: 0.74s, reconstruction error: 3.00
# Epoch 25:	#####################################################	elapsed: 0.76s, reconstruction error: 3.09
# Epoch 26:	#####################################################	elapsed: 0.76s, reconstruction error: 3.00
# Epoch 27:	#####################################################	elapsed: 0.75s, reconstruction error: 2.94
# Epoch 28:	#####################################################	elapsed: 0.75s, reconstruction error: 3.14
# Epoch 29:	#####################################################	elapsed: 0.76s, reconstruction error: 3.05
# Epoch 30:	#####################################################	elapsed: 0.75s, reconstruction error: 2.89
# Epoch 31:	#####################################################	elapsed: 0.77s, reconstruction error: 2.94
# Epoch 32:	#####################################################	elapsed: 0.75s, reconstruction error: 2.96
# Epoch 33:	#####################################################	elapsed: 0.80s, reconstruction error: 2.97
# Epoch 34:	#####################################################	elapsed: 1.18s, reconstruction error: 3.01
# Epoch 35:	#####################################################	elapsed: 1.16s, reconstruction error: 2.96
# Epoch 36:	#####################################################	elapsed: 1.02s, reconstruction error: 2.92
# Epoch 37:	#####################################################	elapsed: 0.76s, reconstruction error: 2.86
# Epoch 38:	#####################################################	elapsed: 0.77s, reconstruction error: 3.04
# Epoch 39:	#####################################################	elapsed: 0.77s, reconstruction error: 2.96
# Epoch 40:	#####################################################	elapsed: 0.75s, reconstruction error: 2.94
# Epoch 41:	#####################################################	elapsed: 0.75s, reconstruction error: 2.93
# Epoch 42:	#####################################################	elapsed: 0.77s, reconstruction error: 2.99
# Epoch 43:	#####################################################	elapsed: 0.77s, reconstruction error: 2.88
# Epoch 44:	#####################################################	elapsed: 0.75s, reconstruction error: 2.89
# Epoch 45:	#####################################################	elapsed: 0.76s, reconstruction error: 2.86
# Epoch 46:	#####################################################	elapsed: 0.78s, reconstruction error: 2.95
# Epoch 47:	#####################################################	elapsed: 1.00s, reconstruction error: 2.85
# Epoch 48:	#####################################################	elapsed: 0.74s, reconstruction error: 2.94
# Epoch 49:	#####################################################	elapsed: 0.78s, reconstruction error: 2.92
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
