# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum, l1_penalty, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    features_in_observation_count = minibatch.shape[1]

    positive_visible = minibatch
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # Positive Phase
    positive_hidden_preactivation = positive_visible @ rbm.W[:, :-1] # Slice-out bias for hidden layer
    positive_hidden[:, :-1] = sigmoid(positive_hidden_preactivation)
    positive_gradient = positive_visible.T @ positive_hidden / observations_count
    
    # Negative Phase
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(positive_hidden.shape[0],
                                                             positive_hidden.shape[1] - 1)
    
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                 negative_visible.shape[1] - 1)
    
    for _ in range(k-1):
          
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(negative_hidden.shape[0],
                                                                                   negative_hidden.shape[1] - 1)
        
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(negative_visible.shape[0],
                                                                                    neagtive_visible.shape[1] - 1)
    
    negative_hidden_preactivation = negative_visible @ rbm.W[:, :-1]
    negative_hidden[:, :-1] = sigmoid(negative_hidden_preactivation)
    negative_gradient = negative_visible.T @ negative_hidden / observations_count
    
    gradient = positive_gradient - negative_gradient
    
    # Regularization
    if rbm.l1_penalty > 0:
        # Use L1
        gradient[:-1, :-1] += rbm.l1_penalty * np.sign(rbm.W[:-1, :-1])
    
    if rbm.l2_penalty > 0:
        # Use L2
        gradient[:-1, :-1] += rbm.l2_penalty * rbm.W[:-1, :-1]
    
    rbm.M = rbm.momentum * rbm.M + rbm.learning_rate * gradient
    rbm.W += rbm.M

# %% [markdown]
# ## Comparison of regularization penalties

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1384/47815768.py in <module>
#       2 L2_PENALTY = 0.0
#       3
# ----> 4 np.random.seed(1234)
#       5 rbm_plain = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)
#       6
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 1.06s, reconstruction error: 26.30
# Epoch 2:	########################################	elapsed: 1.13s, reconstruction error: 21.10
# Epoch 3:	########################################	elapsed: 0.97s, reconstruction error: 18.66
# Epoch 4:	########################################	elapsed: 1.11s, reconstruction error: 17.25
# Epoch 5:	########################################	elapsed: 0.99s, reconstruction error: 16.31
# Epoch 6:	########################################	elapsed: 1.07s, reconstruction error: 14.91
# Epoch 7:	########################################	elapsed: 0.90s, reconstruction error: 13.95
# Epoch 8:	########################################	elapsed: 1.00s, reconstruction error: 13.34
# Epoch 9:	########################################	elapsed: 0.89s, reconstruction error: 12.66
# Epoch 10:	########################################	elapsed: 1.00s, reconstruction error: 12.22
# Epoch 11:	########################################	elapsed: 0.91s, reconstruction error: 11.98
# Epoch 12:	########################################	elapsed: 1.03s, reconstruction error: 11.84
# Epoch 13:	########################################	elapsed: 0.92s, reconstruction error: 11.42
# Epoch 14:	########################################	elapsed: 1.08s, reconstruction error: 11.23
# Epoch 15:	########################################	elapsed: 0.90s, reconstruction error: 11.23
# Epoch 16:	########################################	elapsed: 1.02s, reconstruction error: 11.05
# Epoch 17:	########################################	elapsed: 0.91s, reconstruction error: 11.10
# Epoch 18:	########################################	elapsed: 1.02s, reconstruction error: 10.71
# Epoch 19:	########################################	elapsed: 0.93s, reconstruction error: 10.81
# Epoch 20:	########################################	elapsed: 1.10s, reconstruction error: 10.66
# Epoch 21:	########################################	elapsed: 0.91s, reconstruction error: 10.75
# Epoch 22:	########################################	elapsed: 1.06s, reconstruction error: 10.73
# Epoch 23:	########################################	elapsed: 0.99s, reconstruction error: 10.43
# Epoch 24:	########################################	elapsed: 1.05s, reconstruction error: 10.59
# Epoch 25:	########################################	elapsed: 0.92s, reconstruction error: 10.42
# Epoch 26:	########################################	elapsed: 1.07s, reconstruction error: 10.43
# Epoch 27:	########################################	elapsed: 0.91s, reconstruction error: 10.31
# Epoch 28:	########################################	elapsed: 1.10s, reconstruction error: 10.21
# Epoch 29:	########################################	elapsed: 0.98s, reconstruction error: 10.34
# Epoch 30:	########################################	elapsed: 1.16s, reconstruction error: 10.25
# Epoch 31:	########################################	elapsed: 0.92s, reconstruction error: 10.19
# Epoch 32:	########################################	elapsed: 1.05s, reconstruction error: 10.20
# Epoch 33:	########################################	elapsed: 0.92s, reconstruction error: 10.17
# Epoch 34:	########################################	elapsed: 1.05s, reconstruction error: 10.16
# Epoch 35:	########################################	elapsed: 0.90s, reconstruction error: 10.04
# Epoch 36:	########################################	elapsed: 1.05s, reconstruction error: 10.22
# Epoch 37:	########################################	elapsed: 0.85s, reconstruction error: 10.14
# Epoch 38:	########################################	elapsed: 1.03s, reconstruction error: 10.03
# Epoch 39:	########################################	elapsed: 0.90s, reconstruction error: 10.00
# Epoch 40:	########################################	elapsed: 1.02s, reconstruction error: 10.25
# Epoch 41:	########################################	elapsed: 0.86s, reconstruction error: 10.01
# Epoch 42:	########################################	elapsed: 1.01s, reconstruction error: 10.04
# Epoch 43:	########################################	elapsed: 0.86s, reconstruction error: 10.01
# Epoch 44:	########################################	elapsed: 1.01s, reconstruction error: 10.00
# Epoch 45:	########################################	elapsed: 0.85s, reconstruction error: 9.97
# Epoch 46:	########################################	elapsed: 1.02s, reconstruction error: 9.88
# Epoch 47:	########################################	elapsed: 0.90s, reconstruction error: 10.08
# Epoch 48:	########################################	elapsed: 1.01s, reconstruction error: 9.95
# Epoch 49:	########################################	elapsed: 0.87s, reconstruction error: 9.83
# Epoch 50:	########################################	elapsed: 0.99s, reconstruction error: 9.70
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L1_PENALTY, L2_PENALTY)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.90s, reconstruction error: 26.23
# Epoch 2:	########################################	elapsed: 0.90s, reconstruction error: 21.16
# Epoch 3:	########################################	elapsed: 0.87s, reconstruction error: 18.74
# Epoch 4:	########################################	elapsed: 0.93s, reconstruction error: 17.33
# Epoch 5:	########################################	elapsed: 1.08s, reconstruction error: 16.47
# Epoch 6:	########################################	elapsed: 0.99s, reconstruction error: 15.00
# Epoch 7:	########################################	elapsed: 1.01s, reconstruction error: 14.02
# Epoch 8:	########################################	elapsed: 0.89s, reconstruction error: 13.48
# Epoch 9:	########################################	elapsed: 0.87s, reconstruction error: 12.80
# Epoch 10:	########################################	elapsed: 0.94s, reconstruction error: 12.41
# Epoch 11:	########################################	elapsed: 1.02s, reconstruction error: 12.01
# Epoch 12:	########################################	elapsed: 0.98s, reconstruction error: 11.93
# Epoch 13:	########################################	elapsed: 1.01s, reconstruction error: 11.66
# Epoch 14:	########################################	elapsed: 1.06s, reconstruction error: 11.41
# Epoch 15:	########################################	elapsed: 1.12s, reconstruction error: 11.34
# Epoch 16:	########################################	elapsed: 1.17s, reconstruction error: 11.21
# Epoch 17:	########################################	elapsed: 0.95s, reconstruction error: 11.09
# Epoch 18:	########################################	elapsed: 1.31s, reconstruction error: 10.96
# Epoch 19:	########################################	elapsed: 1.00s, reconstruction error: 10.99
# Epoch 20:	########################################	elapsed: 1.03s, reconstruction error: 10.70
# Epoch 21:	########################################	elapsed: 0.94s, reconstruction error: 10.96
# Epoch 22:	########################################	elapsed: 0.92s, reconstruction error: 10.97
# Epoch 23:	########################################	elapsed: 0.89s, reconstruction error: 10.82
# Epoch 24:	########################################	elapsed: 0.89s, reconstruction error: 10.64
# Epoch 25:	########################################	elapsed: 0.92s, reconstruction error: 10.58
# Epoch 26:	########################################	elapsed: 1.03s, reconstruction error: 10.55
# Epoch 27:	########################################	elapsed: 0.94s, reconstruction error: 10.57
# Epoch 28:	########################################	elapsed: 1.01s, reconstruction error: 10.54
# Epoch 29:	########################################	elapsed: 0.98s, reconstruction error: 10.49
# Epoch 30:	########################################	elapsed: 0.99s, reconstruction error: 10.62
# Epoch 31:	########################################	elapsed: 0.95s, reconstruction error: 10.46
# Epoch 32:	########################################	elapsed: 0.96s, reconstruction error: 10.51
# Epoch 33:	########################################	elapsed: 1.17s, reconstruction error: 10.44
# Epoch 34:	########################################	elapsed: 1.11s, reconstruction error: 10.47
# Epoch 35:	########################################	elapsed: 1.05s, reconstruction error: 10.33
# Epoch 36:	########################################	elapsed: 0.93s, reconstruction error: 10.40
# Epoch 37:	########################################	elapsed: 0.91s, reconstruction error: 10.29
# Epoch 38:	########################################	elapsed: 1.05s, reconstruction error: 10.33
# Epoch 39:	########################################	elapsed: 1.01s, reconstruction error: 10.18
# Epoch 40:	########################################	elapsed: 0.93s, reconstruction error: 10.03
# Epoch 41:	########################################	elapsed: 0.92s, reconstruction error: 10.16
# Epoch 42:	########################################	elapsed: 0.93s, reconstruction error: 10.32
# Epoch 43:	########################################	elapsed: 0.95s, reconstruction error: 10.22
# Epoch 44:	########################################	elapsed: 0.95s, reconstruction error: 10.27
# Epoch 45:	########################################	elapsed: 0.88s, reconstruction error: 10.21
# Epoch 46:	########################################	elapsed: 0.89s, reconstruction error: 10.28
# Epoch 47:	########################################	elapsed: 0.88s, reconstruction error: 10.21
# Epoch 48:	########################################	elapsed: 0.98s, reconstruction error: 10.17
# Epoch 49:	########################################	elapsed: 0.91s, reconstruction error: 10.22
# Epoch 50:	########################################	elapsed: 0.89s, reconstruction error: 10.08
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
def softmax(batch):
    u = np.max(batch, axis=-1, keepdims=True) # bez keepdims (128,10) vs (128,)
    numerator = np.exp(batch - u)
    denominator = np.sum(numerator, axis=-1, keepdims=True)
    return numerator / denominator

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch

    for layer_idx, layer in enumerate(mlp):
        preactivation_z = visible @ layer.W
        activation = layer.activation_fun(preactivation_z)
        layer.activations = append_ones(activation)

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(preactivation_z)

        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (layer.deltas @ layer.W[:-1].T) * prev_layer.d_activations
            # Transposition is needed. layer.W is adjusted to the "forward" direction.
        else:
            visible = batch
        
        gradient = (visible.T @ layer.deltas) / observations_count
        
        if layer.l2_penalty > 0:
            gradient += layer.l2_penalty * layer.W
        
        layer.M = layer.momentum * layer.M - layer.learning_rate * gradient
        layer.W += layer.M

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        # Inicjalizujemy deltas -> różnica między tym co wyszło w sieci a tym co miało wyjść.
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_mlp_training(mlp, train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = 0.9
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")
    
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    minibatch_after_propagation = propagate_up(dbn, layers_count, minibatch)
    rbm = dbn[layers_count]

    return reconstuction_error(rbm, minibatch_after_propagation)

# %%
def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for layer_idx in range(len(dbn)):
        mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

shallow_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in shallow_mlp[:-1]
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.47s, accuracy: 10.10
# Epoch 2:	########################################	elapsed: 0.44s, accuracy: 10.10
# Epoch 3:	########################################	elapsed: 0.44s, accuracy: 8.92
# Epoch 4:	########################################	elapsed: 0.43s, accuracy: 8.92
# Epoch 5:	########################################	elapsed: 0.44s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.43s, accuracy: 15.02
# Epoch 7:	########################################	elapsed: 0.47s, accuracy: 27.15
# Epoch 8:	########################################	elapsed: 0.44s, accuracy: 31.93
# Epoch 9:	########################################	elapsed: 0.45s, accuracy: 33.29
# Epoch 10:	########################################	elapsed: 0.46s, accuracy: 46.86
# Epoch 11:	########################################	elapsed: 0.49s, accuracy: 52.82
# Epoch 12:	########################################	elapsed: 0.41s, accuracy: 58.69
# Epoch 13:	########################################	elapsed: 0.46s, accuracy: 69.29
# Epoch 14:	########################################	elapsed: 0.45s, accuracy: 80.92
# Epoch 15:	########################################	elapsed: 0.46s, accuracy: 84.71
# Epoch 16:	########################################	elapsed: 0.44s, accuracy: 86.90
# Epoch 17:	########################################	elapsed: 0.47s, accuracy: 88.13
# Epoch 18:	########################################	elapsed: 0.45s, accuracy: 89.19
# Epoch 19:	########################################	elapsed: 0.45s, accuracy: 90.03
# Epoch 20:	########################################	elapsed: 0.45s, accuracy: 90.75
# Epoch 21:	########################################	elapsed: 0.44s, accuracy: 91.08
# Epoch 22:	########################################	elapsed: 0.40s, accuracy: 91.51
# Epoch 23:	########################################	elapsed: 0.46s, accuracy: 91.63
# Epoch 24:	########################################	elapsed: 0.41s, accuracy: 91.91
# Epoch 25:	########################################	elapsed: 0.43s, accuracy: 92.00
# Epoch 26:	########################################	elapsed: 0.43s, accuracy: 92.26
# Epoch 27:	########################################	elapsed: 0.39s, accuracy: 92.56
# Epoch 28:	########################################	elapsed: 0.43s, accuracy: 92.74
# Epoch 29:	########################################	elapsed: 0.45s, accuracy: 92.96
# Epoch 30:	########################################	elapsed: 0.40s, accuracy: 93.19
# Epoch 31:	########################################	elapsed: 0.45s, accuracy: 93.09
# Epoch 32:	########################################	elapsed: 0.43s, accuracy: 93.03
# Epoch 33:	########################################	elapsed: 0.44s, accuracy: 93.17
# Epoch 34:	########################################	elapsed: 0.44s, accuracy: 93.60
# Epoch 35:	########################################	elapsed: 0.44s, accuracy: 93.79
# Epoch 36:	########################################	elapsed: 0.46s, accuracy: 93.94
# Epoch 37:	########################################	elapsed: 0.45s, accuracy: 93.88
# Epoch 38:	########################################	elapsed: 0.44s, accuracy: 93.90
# Epoch 39:	########################################	elapsed: 0.44s, accuracy: 93.89
# Epoch 40:	########################################	elapsed: 0.46s, accuracy: 93.78
# Epoch 41:	########################################	elapsed: 0.46s, accuracy: 93.70
# Epoch 42:	########################################	elapsed: 0.46s, accuracy: 93.58
# Epoch 43:	########################################	elapsed: 0.45s, accuracy: 93.53
# Epoch 44:	########################################	elapsed: 0.43s, accuracy: 93.51
# Epoch 45:	########################################	elapsed: 0.44s, accuracy: 93.56
# Epoch 46:	########################################	elapsed: 0.45s, accuracy: 93.55
# Epoch 47:	########################################	elapsed: 0.46s, accuracy: 93.53
# Epoch 48:	########################################	elapsed: 0.45s, accuracy: 93.64
# Epoch 49:	########################################	elapsed: 0.44s, accuracy: 93.77
# Epoch 50:	########################################	elapsed: 0.45s, accuracy: 93.91
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.64s, reconstruction error: 31.78
# Epoch 2:	########################################	elapsed: 0.54s, reconstruction error: 24.90
# Epoch 3:	########################################	elapsed: 0.55s, reconstruction error: 21.47
# Epoch 4:	########################################	elapsed: 0.56s, reconstruction error: 19.07
# Epoch 5:	########################################	elapsed: 0.53s, reconstruction error: 17.78
# Epoch 6:	########################################	elapsed: 0.53s, reconstruction error: 15.28
# Epoch 7:	########################################	elapsed: 0.55s, reconstruction error: 13.30
# Epoch 8:	########################################	elapsed: 0.55s, reconstruction error: 12.52
# Epoch 9:	########################################	elapsed: 0.55s, reconstruction error: 11.80
# Epoch 10:	########################################	elapsed: 0.55s, reconstruction error: 11.40
# Epoch 11:	########################################	elapsed: 0.56s, reconstruction error: 11.11
# Epoch 12:	########################################	elapsed: 0.57s, reconstruction error: 10.75
# Epoch 13:	########################################	elapsed: 0.55s, reconstruction error: 10.40
# Epoch 14:	########################################	elapsed: 0.56s, reconstruction error: 10.31
# Epoch 15:	########################################	elapsed: 0.57s, reconstruction error: 9.99
# Epoch 16:	########################################	elapsed: 0.54s, reconstruction error: 9.89
# Epoch 17:	########################################	elapsed: 0.55s, reconstruction error: 10.07
# Epoch 18:	########################################	elapsed: 0.55s, reconstruction error: 9.66
# Epoch 19:	########################################	elapsed: 0.56s, reconstruction error: 9.53
# Epoch 20:	########################################	elapsed: 0.54s, reconstruction error: 9.68
# Epoch 21:	########################################	elapsed: 0.55s, reconstruction error: 9.62
# Epoch 22:	########################################	elapsed: 0.66s, reconstruction error: 9.47
# Epoch 23:	########################################	elapsed: 0.57s, reconstruction error: 9.39
# Epoch 24:	########################################	elapsed: 0.59s, reconstruction error: 9.35
# Epoch 25:	########################################	elapsed: 0.60s, reconstruction error: 9.33
# Epoch 26:	########################################	elapsed: 0.61s, reconstruction error: 9.30
# Epoch 27:	########################################	elapsed: 0.54s, reconstruction error: 9.20
# Epoch 28:	########################################	elapsed: 0.52s, reconstruction error: 9.15
# Epoch 29:	########################################	elapsed: 0.53s, reconstruction error: 9.00
# Epoch 30:	########################################	elapsed: 0.55s, reconstruction error: 9.02
# Epoch 31:	########################################	elapsed: 0.54s, reconstruction error: 9.06
# Epoch 32:	########################################	elapsed: 0.53s, reconstruction error: 9.00
# Epoch 33:	########################################	elapsed: 0.53s, reconstruction error: 9.10
# Epoch 34:	########################################	elapsed: 0.53s, reconstruction error: 8.92
# Epoch 35:	########################################	elapsed: 0.53s, reconstruction error: 8.98
# Epoch 36:	########################################	elapsed: 0.55s, reconstruction error: 9.00
# Epoch 37:	########################################	elapsed: 0.51s, reconstruction error: 8.94
# Epoch 38:	########################################	elapsed: 0.59s, reconstruction error: 8.90
# Epoch 39:	########################################	elapsed: 0.52s, reconstruction error: 8.84
# Epoch 40:	########################################	elapsed: 0.53s, reconstruction error: 8.89
# Epoch 41:	########################################	elapsed: 0.57s, reconstruction error: 8.69
# Epoch 42:	########################################	elapsed: 0.56s, reconstruction error: 8.76
# Epoch 43:	########################################	elapsed: 0.57s, reconstruction error: 8.71
# Epoch 44:	########################################	elapsed: 0.54s, reconstruction error: 8.72
# Epoch 45:	########################################	elapsed: 0.55s, reconstruction error: 8.75
# Epoch 46:	########################################	elapsed: 0.53s, reconstruction error: 8.64
# Epoch 47:	########################################	elapsed: 0.52s, reconstruction error: 8.70
# Epoch 48:	########################################	elapsed: 0.54s, reconstruction error: 8.66
# Epoch 49:	########################################	elapsed: 0.52s, reconstruction error: 8.58
# Epoch 50:	########################################	elapsed: 0.52s, reconstruction error: 8.61
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.34s, reconstruction error: 19.53
# Epoch 2:	########################################	elapsed: 0.34s, reconstruction error: 14.85
# Epoch 3:	########################################	elapsed: 0.35s, reconstruction error: 12.74
# Epoch 4:	########################################	elapsed: 0.34s, reconstruction error: 11.33
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 10.32
# Epoch 6:	########################################	elapsed: 0.36s, reconstruction error: 8.58
# Epoch 7:	########################################	elapsed: 0.37s, reconstruction error: 7.33
# Epoch 8:	########################################	elapsed: 0.37s, reconstruction error: 6.63
# Epoch 9:	########################################	elapsed: 0.37s, reconstruction error: 6.06
# Epoch 10:	########################################	elapsed: 0.37s, reconstruction error: 5.83
# Epoch 11:	########################################	elapsed: 0.37s, reconstruction error: 5.60
# Epoch 12:	########################################	elapsed: 0.35s, reconstruction error: 5.37
# Epoch 13:	########################################	elapsed: 0.36s, reconstruction error: 5.20
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 5.12
# Epoch 15:	########################################	elapsed: 0.36s, reconstruction error: 5.01
# Epoch 16:	########################################	elapsed: 0.39s, reconstruction error: 4.89
# Epoch 17:	########################################	elapsed: 0.37s, reconstruction error: 4.74
# Epoch 18:	########################################	elapsed: 0.37s, reconstruction error: 4.69
# Epoch 19:	########################################	elapsed: 0.39s, reconstruction error: 4.68
# Epoch 20:	########################################	elapsed: 0.40s, reconstruction error: 4.59
# Epoch 21:	########################################	elapsed: 0.39s, reconstruction error: 4.49
# Epoch 22:	########################################	elapsed: 0.36s, reconstruction error: 4.49
# Epoch 23:	########################################	elapsed: 0.35s, reconstruction error: 4.47
# Epoch 24:	########################################	elapsed: 0.37s, reconstruction error: 4.39
# Epoch 25:	########################################	elapsed: 0.36s, reconstruction error: 4.47
# Epoch 26:	########################################	elapsed: 0.37s, reconstruction error: 4.37
# Epoch 27:	########################################	elapsed: 0.41s, reconstruction error: 4.36
# Epoch 28:	########################################	elapsed: 0.39s, reconstruction error: 4.28
# Epoch 29:	########################################	elapsed: 0.36s, reconstruction error: 4.23
# Epoch 30:	########################################	elapsed: 0.39s, reconstruction error: 4.29
# Epoch 31:	########################################	elapsed: 0.40s, reconstruction error: 4.27
# Epoch 32:	########################################	elapsed: 0.38s, reconstruction error: 4.20
# Epoch 33:	########################################	elapsed: 0.43s, reconstruction error: 4.18
# Epoch 34:	########################################	elapsed: 0.40s, reconstruction error: 4.24
# Epoch 35:	########################################	elapsed: 0.36s, reconstruction error: 4.12
# Epoch 36:	########################################	elapsed: 0.35s, reconstruction error: 4.18
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 4.13
# Epoch 38:	########################################	elapsed: 0.36s, reconstruction error: 4.10
# Epoch 39:	########################################	elapsed: 0.36s, reconstruction error: 4.12
# Epoch 40:	########################################	elapsed: 0.35s, reconstruction error: 4.03
# Epoch 41:	########################################	elapsed: 0.36s, reconstruction error: 4.15
# Epoch 42:	########################################	elapsed: 0.36s, reconstruction error: 4.15
# Epoch 43:	########################################	elapsed: 0.36s, reconstruction error: 4.12
# Epoch 44:	########################################	elapsed: 0.40s, reconstruction error: 4.02
# Epoch 45:	########################################	elapsed: 0.37s, reconstruction error: 4.11
# Epoch 46:	########################################	elapsed: 0.40s, reconstruction error: 4.07
# Epoch 47:	########################################	elapsed: 0.37s, reconstruction error: 4.02
# Epoch 48:	########################################	elapsed: 0.37s, reconstruction error: 3.97
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 4.01
# Epoch 50:	########################################	elapsed: 0.36s, reconstruction error: 4.02
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.47s, accuracy: 93.45
# Epoch 2:	########################################	elapsed: 0.47s, accuracy: 94.73
# Epoch 3:	########################################	elapsed: 0.45s, accuracy: 95.28
# Epoch 4:	########################################	elapsed: 0.51s, accuracy: 95.61
# Epoch 5:	########################################	elapsed: 0.48s, accuracy: 95.76
# Epoch 6:	########################################	elapsed: 0.45s, accuracy: 96.03
# Epoch 7:	########################################	elapsed: 0.46s, accuracy: 96.09
# Epoch 8:	########################################	elapsed: 0.47s, accuracy: 96.23
# Epoch 9:	########################################	elapsed: 0.49s, accuracy: 96.39
# Epoch 10:	########################################	elapsed: 0.50s, accuracy: 96.46
# Epoch 11:	########################################	elapsed: 0.47s, accuracy: 96.47
# Epoch 12:	########################################	elapsed: 0.48s, accuracy: 96.47
# Epoch 13:	########################################	elapsed: 0.48s, accuracy: 96.52
# Epoch 14:	########################################	elapsed: 0.52s, accuracy: 96.57
# Epoch 15:	########################################	elapsed: 0.51s, accuracy: 96.61
# Epoch 16:	########################################	elapsed: 0.45s, accuracy: 96.62
# Epoch 17:	########################################	elapsed: 0.48s, accuracy: 96.64
# Epoch 18:	########################################	elapsed: 0.47s, accuracy: 96.69
# Epoch 19:	########################################	elapsed: 0.47s, accuracy: 96.76
# Epoch 20:	########################################	elapsed: 0.47s, accuracy: 96.79
# Epoch 21:	########################################	elapsed: 0.47s, accuracy: 96.81
# Epoch 22:	########################################	elapsed: 0.46s, accuracy: 96.83
# Epoch 23:	########################################	elapsed: 0.46s, accuracy: 96.81
# Epoch 24:	########################################	elapsed: 0.47s, accuracy: 96.83
# Epoch 25:	########################################	elapsed: 0.48s, accuracy: 96.83
# Epoch 26:	########################################	elapsed: 0.43s, accuracy: 96.88
# Epoch 27:	########################################	elapsed: 0.46s, accuracy: 96.91
# Epoch 28:	########################################	elapsed: 0.45s, accuracy: 96.90
# Epoch 29:	########################################	elapsed: 0.48s, accuracy: 96.90
# Epoch 30:	########################################	elapsed: 0.48s, accuracy: 96.90
# Epoch 31:	########################################	elapsed: 0.52s, accuracy: 96.94
# Epoch 32:	########################################	elapsed: 0.49s, accuracy: 96.95
# Epoch 33:	########################################	elapsed: 0.50s, accuracy: 96.96
# Epoch 34:	########################################	elapsed: 0.48s, accuracy: 96.96
# Epoch 35:	########################################	elapsed: 0.43s, accuracy: 96.95
# Epoch 36:	########################################	elapsed: 0.47s, accuracy: 96.96
# Epoch 37:	########################################	elapsed: 0.45s, accuracy: 96.97
# Epoch 38:	########################################	elapsed: 0.43s, accuracy: 96.98
# Epoch 39:	########################################	elapsed: 0.45s, accuracy: 96.99
# Epoch 40:	########################################	elapsed: 0.42s, accuracy: 96.99
# Epoch 41:	########################################	elapsed: 0.43s, accuracy: 97.00
# Epoch 42:	########################################	elapsed: 0.46s, accuracy: 97.01
# Epoch 43:	########################################	elapsed: 0.46s, accuracy: 97.02
# Epoch 44:	########################################	elapsed: 0.44s, accuracy: 97.01
# Epoch 45:	########################################	elapsed: 0.45s, accuracy: 97.02
# Epoch 46:	########################################	elapsed: 0.45s, accuracy: 97.02
# Epoch 47:	########################################	elapsed: 0.40s, accuracy: 97.00
# Epoch 48:	########################################	elapsed: 0.45s, accuracy: 97.01
# Epoch 49:	########################################	elapsed: 0.45s, accuracy: 97.02
# Epoch 50:	########################################	elapsed: 0.44s, accuracy: 97.03
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY)
]

deep_dbn = [
    Rbm(mlp_layer.visible_size,
        mlp_layer.hidden_size,
        LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY) for mlp_layer in deep_mlp[:-1]
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
